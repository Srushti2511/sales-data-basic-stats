# %%
import pandas as pd
df = pd.read_csv(r"C:\Users\Shrushti\Downloads\Basic stats - 1 (1)\Basic stats - 1\sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df["Total Sales Value"].mean()
#Interpretation
#The average total sales value. It’s higher than the median, suggesting right-skewness.
# Out:
# 33812.83555555555

# %%
df["Total Sales Value"].median()
#The middle value when the data is sorted. Much lower than the mean, confirming positive skewness (a few high values pulling the mean up).
# Out:
# 5700.0

# %%
df["Total Sales Value"].mode()
#The most frequently occurring sales value. This suggests that ₹24,300 is a common sales value in the dataset.
# Out:
# 0    24300
# Name: Total Sales Value, dtype: int64

# %%
df["Total Sales Value"].std()
#Indicates high variability in sales values. The values are widely spread out from the mean.
# Out:
# 50535.07417255328

# %%
df["Volume"].mean()
#The average volume. Slightly above the median, indicating a mild right skew.
# Out:
# 5.066666666666666

# %%
df["Volume"].median()
#The middle value of the volume data. Lower than the mean, confirming positive skewness.
# Out:
# 4.0

# %%
df["Volume"].mode()
#The most frequently occurring volume, meaning 3 is the most common value
# Out:
# 0    3
# Name: Volume, dtype: int64

# %%
df["Volume"].std()
#Indicates that the volume values are moderately spread out from the mean
# Out:
# 4.231602391213926

# %%
df["Avg Price"].mean()
#This is the arithmetic average of all values. It's quite high, likely due to one or more large values (outliers).
# Out:
# 10453.433333333332

# %%
df["Avg Price"].median()
#The middle value when data is sorted. It’s much lower than the mean, confirming the presence of high-value outliers pulling the mean up.
# Out:
# 1450.0

# %%
df["Avg Price"].mode()
#These are the most frequently occurring values in the dataset. Multiple modes suggest the data may be multimodal (has several peaks in distribution).
# Out:
# 0     400
# 1     450
# 2     500
# 3    1300
# 4    8100
# Name: Avg Price, dtype: int64

# %%
df["Avg Price"].std()
# This measures how spread out the data is from the mean. A very high standard deviation indicates high variability in prices, again likely due to outliers.
# Out:
# 18079.90483993645

# %%
df["Discount Rate (%)"].mean()
#The average discount rate across all records is around 15.15%.
# Out:
# 15.155241895330914

# %%
df["Discount Rate (%)"].median()
#The middle value is a bit higher than the mean, suggesting a slightly left-skewed distribution (more lower values pulling the mean down).
# Out:
# 16.57776564929597

# %%
df["Discount Rate (%)"].mode()
#Since there are many unique values (450 modes), it indicates that the discount rates have a continuous-like spread with very few exact repeats — or almost every value is unique.
# Out:
# 0       5.007822
# 1       5.055218
# 2       5.059801
# 3       5.072124
# 4       5.084108
#          ...
# 445    19.940610
# 446    19.965340
# 447    19.976879
# 448    19.982257
# 449    19.992407
# Name: Discount Rate (%), Length: 450, dtype: float64

# %%
df["Discount Rate (%)"].std()
#This measures how much discount rates typically deviate from the mean of 15.15%. A standard deviation of 4.22 is moderate, suggesting values are reasonably clustered around the mean without extreme variation.
# Out:
# 4.220602153325511

# %%
df["Discount Amount"].mean()
#The average discount amount is around 3346.5 units.
# Out:
# 3346.499424342415

# %%
df["Discount Amount"].median()
#The middle value is much lower than the mean, indicating a right-skewed distribution — meaning some very high discount amounts (outliers) are pulling the mean up.
# Out:
# 988.9337332382784

# %%
df["Discount Amount"].mode()
#Since there are many unique values (450 modes), it suggests that discount amounts vary widely and most values are unique.
# Out:
# 0         69.177942
# 1         73.025199
# 2         93.649161
# 3         94.682735
# 4        102.705757
#            ...
# 445    17900.983733
# 446    21153.498820
# 447    21496.675367
# 448    25328.224204
# 449    25738.022194
# Name: Discount Amount, Length: 450, dtype: float64

# %%
df["Discount Amount"].std()
# This is quite large relative to the mean and median, confirming high variability in discount amounts. A wide spread like this indicates outliers or a large range of values.
# Out:
# 4509.9029633539985

# %%
df["Net Sales Value"].mean()
#The average sales value is around 30,466 units.
# Out:
# 30466.336131270138

# %%
df["Net Sales Value"].median()
#The middle value is much lower than the mean, indicating a strong right-skewed distribution — where a few very large sales values are pulling the average up.
# Out:
# 4677.788059301853

# %%
df["Net Sales Value"].mode()
#With 450 unique values, almost every value is unique or rarely repeated — so it behaves like continuous data.
# Out:
# 0         326.974801
# 1         330.822058
# 2         466.350839
# 3         485.317265
# 4         496.607104
#            ...
# 445    162603.186379
# 446    163915.971000
# 447    163967.080070
# 448    166263.161348
# 449    179507.479049
# Name: Net Sales Value, Length: 450, dtype: float64

# %%
df["Net Sales Value"].std()
# This is very high — even larger than the mean — confirming extreme spread and high variability in sales values.
# Out:
# 46358.656624066934

# %%
#or 
import matplotlib.pyplot as plt

plt.hist(df['Volume'],bins=10,edgecolor='black',color='skyblue')
plt.title('Histogram of Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Volume'], edgecolor='yellow')
plt.title('Histogram of Volume')

#1)Shape of the Distribution:
#The histogram is right-skewed(positively skewed).
#1.Most of the data is concentrated on the left side(low volume values).
#2.There are fewer instances of high-volume values that stretch out to the right.

#2)Frequency Pattern:
#The highest bar is in the first bin(leftmost),indicating that a large number of observations fall into the smallest volume range.
#The frequency of values decreases rapidely as volume increases.

#3)Outliers:
# A small number of entries fall into higher volume ranges(the rightmost bars).
# These are potential outliers,as they occur infrequently and are far from the bulk of the data.

#4)Inference
#1.Most transactions have low volumes.
#2.A few transactions have exceptionally high volumes,which could indicate large bulk purchases or data entry anomalies.
#3.Due to the skewness,measures like median wouls better represent the central tendency than  the mean.
# Out:
# Text(0.5, 1.0, 'Histogram of Volume')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Avg Price'], edgecolor='yellow')
plt.title('Avg Price')


#Skewness:
#1) The distribution is positively skewed (right-skewed).
#2) Most of the data points are concentrated in the lower range (0 - 10,000).
#3) There are fewer values in the higher ranges (right tail), indicating long tail to the right.

# Presence of Outliers:
#1) There are clear outliers in the 50,000–60,000 range, with visible bars at those values.
#2) This indicates a small number of unusually high values compared to the bulk of the data.


#Inferences:
#1) Most data values are small, indicating the variable measured tends to stay in a lower range for most observations.
#2) The few very large values (above 50,000) are statistical outliers and may need further investigation — they could be anomalies or special cases.
#3)Due to the right skew, using the median rather than the mean is advisable when summarizing central tendency, as the mean may be distorted by extreme values.
# Out:
# Text(0.5, 1.0, 'Avg Price')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Total Sales Value'], edgecolor='yellow')
plt.title('Total Sales Value')

#Skewness:
#1) The data is positively skewed (right-skewed).
#2) Most of the values are concentrated on the left (lower sales values), and the tail stretches out towards the right (higher sales values).

#Outliers:
#1)Since very few values fall beyond 100,000 and up to 200,000, those can be considered as outliers or rare high-value sales.

#Inferences:
#1) Majority of transactions are of low value, likely under ₹25,000.
#2) The median would be a better representation of central tendency than the mean in this skewed distribution
# Out:
# Text(0.5, 1.0, 'Total Sales Value')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Discount Rate (%)'], edgecolor='yellow')
plt.title('Discount Rate (%)')

#Skewness:
#1) The distribution appears to be negatively skewed (left-skewed).
#2) Most of the data is concentrated on the higher end (around 16%–20%), with fewer observations on the lower end (5%–10%).

#Outliers:
#1)No extreme values appear to be outliers. All bars seem to lie within a reasonable and expected discount range (5%–20%).

#Inferences:
#1) Most items or transactions are offered at higher discounts, particularly around 18–20%, indicating a possible pricing strategy focused on heavy discounts.
#2)This pattern might imply strategic discount clustering — for example, attracting customers with high discounts or simplifying pricing tiers.
# Out:
# Text(0.5, 1.0, 'Discount Rate (%)')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Discount Amount'], edgecolor='yellow')
plt.title('Discount Amount')

#Skewness:
#1) The distribution is positively skewed (right-skewed).
#2) Most values are concentrated on the left side (lower discount amounts).
#3) A long tail extends to the right, indicating the presence of some higher discount amounts.

#Outliers:
#1) While no extreme spikes are seen, higher discount values (above ₹15,000) are rare and could be considered mild outliers depending on the business context.

#Inferences:
#1) Most discounts given are small in value, likely indicating that smaller discounts are more common across transactions or products.
#2) A few transactions involve large discount amounts, which might be tied to high-value sales, bulk purchases, or special offers.
#3) The mean discount amount might be inflated due to the right-skewed nature, so the median would better represent the central value.
# Out:
# Text(0.5, 1.0, 'Discount Amount')

# %%
import matplotlib.pyplot as plt
import pandas as pd
data = pd.read_csv("Sales_data_with_discounts.csv")
plt.hist(data['Net Sales Value'], edgecolor='yellow')
plt.title('Net Sales Value')

#Skewness:
#1) The histogram is right-skewed (positively skewed).
#2) Most data points are concentrated in the lower range (0–25,000).
#3) A long tail extends to the right, indicating fewer instances of high sales values (up to 175,000).

#Outliers:
#1) There is a potential presence of outliers or extreme values beyond 100,000. These are significantly less frequent than the bulk of the data.
#2) These could represent unusually high sales which may require further business investigation (e.g., large corporate orders or seasonal spikes).

#Inferences:
#1) Business Insight: Most customers generate low net sales. You may want to analyze this group for volume-based sales strategies.
#2) Target High-Value Clients: The sparse high-value sales suggest potential for niche targeting—investigate what drives these large transactions.
# Out:
# Text(0.5, 1.0, 'Net Sales Value')

# %%
#Boxplot
plt.boxplot(data['Volume'])
plt.title('Volume')
plt.show()

#Outliers:
#1) The dots (●) above the top whisker line are outliers.
#2) In your plot, several values appear above 10 on the Y-axis — these are considered outliers because they lie beyond the upper bound of the typical data range.

#Interquartile Range (IQR):
#1) The IQR is the range between the first quartile (Q1) and third quartile (Q3) — it represents the middle 50% of your data.

#Findings
#1) The majority of your Volume values are between around 2 and 10.
#2) The median (middle line in the box) seems around 4-5.
#3)There are a significant number of outliers above 10, with extreme values even going beyond 30.

# %%
plt.boxplot(data['Avg Price'])
plt.title('Avg Price')
plt.show()

#Outliers:
#1) The circles (●) above the upper whisker line represent outliers.
#1) In this case, we can see several points well above 20,000 — going up to 60,000 — which are significantly higher than the rest of the data.
#1) These are extreme values compared to the majority of prices.

#Interquartile Range (IQR):
#1) The box represents the interquartile range (IQR), which is the difference between:
# Q3 (75th percentile) — top of the box
# Q1 (25th percentile) — bottom of the box
#The line inside the box shows the median (Q2).
#In plot:
# Most of average prices are below 10,000.
# The whiskers extend to the typical price range — anything above this is marked as an outlier.

#Findings:
#1) The distribution is right-skewed (positively skewed).
#2) There are several very high outliers around 20,000 to 60,000.

# %%
plt.boxplot(data['Total Sales Value'])
plt.title('Total Sales Value')
plt.show()

#Outliers:
#1) The circles (●) above the top whisker represent outliers.
#2) In your plot, multiple points appear above 125,000, with some even approaching 200,000 — these are extreme values significantly higher than the rest of the dataset

#Interquartile Range (IQR):
# The box in the boxplot shows the middle 50% of data — from:
# Q1 (25th percentile) — bottom of the box
# Q3 (75th percentile) — top of the box
# The line inside the box is the median (Q2).
# The whiskers extend to 1.5 × IQR from the quartiles.
# Any data points beyond the whiskers are plotted individually as outliers.
#From plot:
#1) Most of Total Sales Values are under 100,000.
#2) The IQR range (box size) is quite wide, indicating notable spread within typical values.
#3) The presence of many high outliers suggests considerable variation and a right-skewed distribution.

#Findings:
#1) Right-skewed distribution — a few transactions with exceptionally high sales values drive up the average and increase overall variability.
#2) Many high outliers beyond 125,000, up to nearly 200,000.

# %%
plt.boxplot(data['Discount Rate (%)'])
plt.title('Discount Rate (%)')
plt.show()

# Interquartile Range (IQR) & Outliers:
# While a histogram doesn’t directly show IQR or outliers like a boxplot, you can still estimate:
# Q1 and Q3 by identifying the ranges covering the middle 50% of data.
# From your histogram, since most values are clustered between 5% and 20%, with a long right tail, the IQR likely lies between ~10% to 19%.
# No extreme low outliers (since no negative discounts) but you might have outliers if there were any values much above 20% — which doesn’t seem to be the case here.

#Findings:
#1) Majority of discount rates are concentrated between 16% and 20%, with a sharp increase starting at 15%.
#2) Relatively fewer values in the 5% to 10% range.
#3) This suggests businesses or transactions predominantly offer higher discounts.

# %%
plt.boxplot(data['Discount Amount'])
plt.title('Discount Amount')
plt.show()

#Interquartile Range (IQR):
#1) The box (middle 50%) lies roughly between around 1,000 to 5,000 (estimated visually).
#2) This represents the range between Q1 (25th percentile) and Q3 (75th percentile).
# The IQR can be approximated as:
# \{IQR} = Q3 - Q1 \approx 5000 - 1000 = 4000

#Outliers:
# Any point beyond 1.5 × IQR above Q3 or below Q1 is considered an outlier.
# Here, there are many outliers:
# Several values above 10,000
# Extreme outliers extending up to 25,000+

#Findings:
#1) Most discount amounts are concentrated between 1,000 and 5,000.
#2) A significant number of outliers indicate some transactions had exceptionally high discounts — possibly for high-value purchases or bulk sales.
#3) This kind of distribution is positively skewed, as the majority of values are lower, with a long tail of higher values.

# %%
plt.boxplot(data['Net Sales Value'])
plt.title('Net Sales Value')
plt.show()

#Interquartile Range (IQR):
#1) The box (middle 50%) stretches approximately from 10,000 to 50,000.
# So the estimated:
# \{IQR} = Q3 - Q1 \approx 50,000 - 10,000 = 40,000

#Outliers:
# Data points beyond Q3 + 1.5 × IQR are considered outliers.
# Here, many values above 120,000 are marked as outliers — visible as small circles stacked above the upper whisker.
# The outliers range from 125,000 up to about 180,000+.

#Findings:
#1) Most net sales values fall between 10,000 and 50,000.
#2) Significant number of outliers indicate transactions with extremely high net sales.
#3) The distribution is positively skewed (right-skewed), with a long tail of higher values.

# %%
plt.figure(figsize=(8, 6))
data['City'].value_counts().plot(kind='bar', color='Pink')
plt.title('Bar Chart of City')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

#Analysis for City

# The bar chart of City displays the frequency of transactions in each city. 
# It indicates that most transactions occur in City C, followed by other cities.
# This insight can be useful for understanding the distribution of sales across different locations.

# %%
plt.figure(figsize=(8, 6))
data['Brand'].value_counts().plot(kind='bar', color='Pink')
plt.title('Bar Chart of Brand')
plt.xlabel('Brand')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

#Analysis for Brand

# The bar chart of Brand shows the frequency of transactions for each brand. 
# It reveals that RealU is the most popular brand, followed by other brands.
# This information can be valuable for analyzing the market share of different brands.

# %%
### Explanation of Standardization (Z-score Normalization)

# Standardization, also known as Z-score normalization, is a technique used to transform numerical variables to have a mean of 0 and a standard deviation of 1. This process involves subtracting the mean (mu) from each value and then dividing by the standard deviation (sigma). 
# This standardizes the distribution of the data, making it easier to compare variables with different scales and improving the performance of analytical models.

# %%
# Displaying summary statistics before standardization
print("Summary Statistics Before Standardization:")
print(data.describe())
# Out:
# Summary Statistics Before Standardization:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# ...

# %%
# Importing necessary libraries
from sklearn.preprocessing import StandardScaler

# Selecting numerical columns for standardization
numerical_columns = ['Volume', 'Avg Price', 'Total Sales Value', 'Discount Rate (%)', 'Discount Amount', 'Net Sales Value']
numerical_columns
# Out:
# ['Volume',
#  'Avg Price',
#  'Total Sales Value',
#  'Discount Rate (%)',
#  'Discount Amount',
#  'Net Sales Value']

# %%
# Standardizing numerical columns
scaler = StandardScaler()
scaler
# Out:
# StandardScaler()

# %%
data_standardized = data.copy()  # Creating a copy of the original dataset
data_standardized[numerical_columns] = scaler.fit_transform(data[numerical_columns])
data_standardized[numerical_columns]
# Out:
#        Volume  Avg Price  Total Sales Value  Discount Rate (%)  \
# 0    2.350029   0.091173           2.925721          -0.830289
# 1    1.167129  -0.019570           1.330995          -0.852661
# 2    0.457388   0.312659           1.562775          -1.351631
# 3    0.220808   0.534146           1.719276          -1.949723
# 4   -0.488932  -0.130313          -0.188452           0.673739
# ..        ...        ...                ...                ...
# 445 -0.725512  -0.506840          -0.618334           0.076009
# 446  0.220808  -0.434857          -0.360801           0.451097
# 447 -0.725512  -0.490229          -0.606448           0.903793
# 448 -0.488932  -0.473617          -0.556923           0.388474
# 449 -0.962092  -0.407171          -0.608429           0.042235
#
#      Discount Amount  Net Sales Value
# 0           3.952816         2.804756
# 1           1.849014         1.271026
# 2           1.622995         1.545675
# 3           1.113807         1.765810
# ...

# %%
# Displaying summary statistics after standardization
print("\nSummary Statistics After Standardization:")
print(data_standardized.describe())
# Out:
# Summary Statistics After Standardization:
#              Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  4.500000e+02  4.500000e+02       4.500000e+02       4.500000e+02
# mean   6.118562e-17  3.157968e-17       1.578984e-17      -3.552714e-17
# std    1.001113e+00  1.001113e+00       1.001113e+00       1.001113e+00
# min   -9.620925e-01 -5.627654e-01      -6.619170e-01      -2.406935e+00
# 25%   -4.889322e-01 -5.530754e-01      -6.163534e-01      -2.823066e-01
# 50%   -2.523521e-01 -4.985344e-01      -5.569226e-01       3.374180e-01
# 75%    2.208081e-01 -1.957016e-02       3.840648e-01       7.019781e-01
# max    6.135311e+00  2.749009e+00       3.220894e+00       1.147360e+00
#
#        Discount Amount  Net Sales Value
# count     4.500000e+02     4.500000e+02
# mean     -5.526444e-17     1.973730e-17
# std       1.001113e+00     1.001113e+00
# min      -7.275032e-01    -6.508581e-01
# 25%      -6.406462e-01    -6.103625e-01
# ...

# %%
# Displaying comparison of data distributions before and after standardization
for column in numerical_columns:
    plt.figure(figsize=(10, 4))
    plt.subplot(1, 2, 1)
    plt.hist(data[column], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Distribution of {column} (Before Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.subplot(1, 2, 2)
    plt.hist(data_standardized[column], bins=20, color='salmon', edgecolor='black')
    plt.title(f'Distribution of {column} (After Standardization)')
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.tight_layout()
    plt.show()

# %%
#### Need for Converting Categorical Data into Dummy Variables (One-Hot Encoding)

# In many machine learning algorithms, categorical variables cannot be directly used as inputs. One-hot encoding is a technique used to convert categorical variables into a format that can be provided to machine learning algorithms. 
# It creates binary (0 or 1) columns for each category in the categorical variable. This ensures that the categorical data is represented in a numerical format, allowing machine learning models to interpret and process it effectively.

# %%
# Displaying a portion of the dataset before one-hot encoding
print("Dataset Before One-Hot Encoding:")
print(data.head())
# Out:
# Dataset Before One-Hot Encoding:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# ...

# %%
# Performing one-hot encoding on categorical columns
data_encoded = pd.get_dummies(data)

# %%
# Displaying a portion of the transformed dataset after one-hot encoding
print("\nDataset After One-Hot Encoding:")
print(data_encoded.head())
# Out:
# Dataset After One-Hot Encoding:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102961
# 2       7      16100             112700           9.456886     10657.910157
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0    160346.501180             True            False            False
# 1     89323.897039             True            False            False
# 2    102042.089843             True            False            False
# 3    112235.925298             True            False            False
# 4     19927.053770             True            False            False
#
# ...

# %%
#### Key Findings from Descriptive Analytics and Data Visualizations

1. Numerical Columns:
   - The mean Volume of sales is 5.07 units, with a median of 4 units, indicating a slightly right-skewed distribution.
   - Total Sales Value has a mean of 33812.84 and a median of 5700, suggesting a right-skewed distribution with some transactions having 
     considerably higher sales values.
   - Discount Amount and Net Sales Value exhibit similar patterns, with a wide range of values and a right-skewed distribution.

2. Data Visualization:
   - Histograms and boxplots revealed the distribution and presence of outliers in numerical variables.
   - Bar charts for categorical columns illustrated the frequency of transactions in each category, providing insights into the distribution of 
     sales across different cities and brands.

# %%
#### Reflection on the Importance of Data Preprocessing Steps

1. Standardization:
   - Standardizing numerical variables ensures that they are on the same scale, improving the performance of analytical models.
   - By scaling the data to have a mean of 0 and a standard deviation of 1, standardization facilitates accurate pattern recognition in the data.

2. One-Hot Encoding:
   - One-hot encoding transforms categorical variables into a numerical format suitable for machine learning algorithms.
   - This process enables models to interpret categorical data effectively and make accurate predictions based on the transformed dataset.

# %%
# In conclusion, data preprocessing steps like standardization and one-hot encoding are essential for ensuring the quality and usability of the dataset in data analysis and machine learning tasks. These steps enable us to extract meaningful insights, build accurate models, and make informed decisions based on the data.
